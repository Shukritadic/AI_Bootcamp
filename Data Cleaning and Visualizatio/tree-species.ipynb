# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/victoria-bc-city-tree-species-data/Tree_Species.csv

# %%
df =pd.read_csv('/kaggle/input/victoria-bc-city-tree-species-data/Tree_Species.csv')

# %%
df.head()

# %%
df.info()

# %%
df.shape

# %%
df.describe()

# %%
df.isnull().sum()

# %%
df = df.drop(['Parks','SideOfParcel'], axis=1)

# %%
df.columns

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
plt.figure(figsize=(16,4))
sns.countplot(data=df, x='Height')
plt.show()

# %%
median1 = df['Height'].median()
median1

# %%
df['Height']=df['Height'].fillna(median1)

# %%
df['Height'].isnull().sum()

# %%
plt.figure(figsize=(8,6))
sns.countplot(data=df, x='Trunks')
plt.show()

# %%
median2 = df['Trunks'].median()
median2

# %%
df['Trunks'] =df['Trunks'].fillna(median2)

# %%
df['Trunks'].isnull().sum()

# %%
plt.figure(figsize=(16,4))
sns.countplot(data=df, x='Width')
plt.show()

# %%
median3 = df['Width'].median()
median3

# %%
df['Width'] = df['Width'].fillna(median3)

# %%
df['Width'].isnull().sum()

# %%
mode1 = df['Area'].mode()[0]
mode1

# %%
df['Area'] = df['Area'].fillna(mode1)

# %%
df['Area'].isnull().sum()

# %%
mode2 = df['Street'].mode()[0]
mode2

# %%
df['Street'] = df['Street'].fillna(mode2)

# %%
mode3 = df['OnStreet'].mode()[0]
mode3

# %% [markdown]
# mode2

# %%
df['OnStreet'] = df['OnStreet'].fillna(mode3)

# %%
mode4 = df['FromStreet'].mode()[0]
mode4

# %%
df['FromStreet'] = df['FromStreet'].fillna(mode4)

# %%
mode5 = df['ToStreet'].mode()[0]
mode5

# %%
df['ToStreet'] = df['ToStreet'].fillna(mode5)

# %%
mode6 = df['BotanicalName'].mode()[0]
mode6

# %%
df['BotanicalName'] = df['BotanicalName'].fillna(mode6)

# %%
mode7 = df['CommonName'].mode()[0]
mode7

# %%
df['CommonName'] = df['BotanicalName'].fillna(mode7)

# %%
df.isnull().sum()

# %%
mode8 = df['Species'].mode()[0]
mode8

# %%
df['Species'] = df['Species'].fillna(mode7)

# %%
mode9 = df['GrowSpace'].mode()[0]
mode9

# %%
df['GrowSpace'] = df['GrowSpace'].fillna(mode9)

# %%
mode10 = df['TreeCategory'].mode()[0]
mode10

# %%
df['TreeCategory'] = df['TreeCategory'].fillna(mode10)

# %%
plt.figure(figsize=(16,4))
sns.countplot(data=df, x='DiameterAtBreastHeight')
plt.show()

# %%
median4 = df['DiameterAtBreastHeight'].median()
median4

# %%
df['DiameterAtBreastHeight'] = df['DiameterAtBreastHeight'].fillna(median4)

# %%
df.isnull().sum()

# %%
import pandas as pd
df=pd.get_dummies(df,columns=['Street','OnStreet','ToStreet',
                              'FromStreet','Species','GrowSpace','TreeCategory',
                              'Area','BotanicalName',
                              'CommonName'],drop_first = True)

# %%
df.head()
